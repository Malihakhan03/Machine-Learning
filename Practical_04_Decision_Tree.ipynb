# %% [markdown]
# <a href="https://colab.research.google.com/github/Malihakhan03/Machine-Learning/blob/main/Practical_04_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **31/01/26: practical 4 Aim: to build and evaluate a decision tree model for classification tasks and study the effect of tree depth and splitting criteria**

# %% [markdown]
# MALIHA KHAN CS23054

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path="/content/drive/MyDrive/Datasets-ML-Practical/daily_weather[4].csv" #Replace path with your dataset's csv file path
df=pd.read_csv(path)
df.head(5)

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df.columns

# %%
#data cleaning if output is true than there is null value
df.isnull().any().any()

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
#print the rows with missing values
df[df.isnull().any(axis=1)]

# %%
#we do not need to number the rows as pandas its own indexing
del df['number']
df.columns

# %%
df.shape

# %%
before_rows=df.shape[0]
df=df.dropna()
after_rows=df.shape[0]

print("before rows:",before_rows)
print("after rows:",after_rows )
print("The number of dropped rows are:",before_rows-after_rows)
#print("The number of dropped rows are{}".format(before_rows-after_rows))

# %%
df.shape

# %%
#convert to a classification task
#binarize the relative humidity_3pm to 0 or 1
#classifying the data into two categories (binary problem)by setting a desired value (24.99,in this case)to
#and anything above is high(1)and anything below is low(0).
clean_data=df.copy()
clean_data['high_humidity_label']=(clean_data['relative_humidity_3pm']>24.99)*1
print(clean_data['high_humidity_label'])

# %%
clean_data.columns

# %%
clean_data

# %%
del clean_data['relative_humidity_9am']
del clean_data['relative_humidity_3pm']
clean_data.columns

# %%
clean_data.shape

# %%
#split dataset into independent and dependent
X=clean_data.iloc[:,:-1]
print(X)

# %%
y=clean_data.iloc[:,-1]
print(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=42)

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %%
#Standardization

from sklearn.preprocessing import StandardScaler
scaling=StandardScaler()
X_train=scaling.fit_transform(X_train)
X_test=scaling.fit_transform(X_test)

# %%
X_train

# %%
#fit the model on the training set using the decision tree classifier
humidity_classifier=DecisionTreeClassifier(max_leaf_nodes=10,random_state=0)
humidity_classifier.fit(X_train,y_train)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(humidity_classifier,filled=True)

# %%
#prediction
y_pred=humidity_classifier.predict(X_test)
print(y_pred)

# %%
#Accuracy Score, Classification report aad confusion matrix
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))

# %%
print(classification_report(y_pred,y_test))
